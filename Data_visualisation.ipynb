# %%
import matplotlib.pyplot as plt

# %%
uniform_positive = []
uniform_negative = []
for x in pos_result:
    for y in neg_result:
        if x[0] == y[0]:
            uniform_positive.append(x)
            uniform_negative.append(y)

# %%
len(pos_result)
# Out:
# 94

# %%
len(uniform_positive)
# Out:
# 81

# %%
len(neg_result)
# Out:
# 102

# %%
len(uniform_negative)
# Out:
# 81

# %%
word_list_pos = []
value_list_pos = []
for t in uniform_positive:
    (w,v) = t
    word_list_pos.append(w)
    value_list_pos.append(v)

# %%
word_list_pos[0:5]
# Out:
# ['good', 'great', 'much', 'little', 'ive']

# %%
value_list_pos[0:5]
# Out:
# [0.009475792668990048,
#  0.008892041511500321,
#  0.004113792720088774,
#  0.003974134377220464,
#  0.0035326310250749734]

# %%
word_list_neg = []
value_list_neg = []
for t in uniform_negative:
    (w,v) = t
    word_list_neg.append(w)
    value_list_neg.append(v)

# %%
word_list_neg[0:5]
# Out:
# ['good', 'great', 'much', 'little', 'ive']

# %%
value_list_neg[0:5]
# Out:
# [0.006216176343667268,
#  0.002451012695523001,
#  0.004007926570805781,
#  0.002394467216164014,
#  0.0024272040726350066]

# %%
# plot 8 graphs, and each graph contains the comparison of 10 words which are in both pos and neg words
i = 0
j = 10
while True:
    plt.bar(x, value_list_pos[i:j], width=width, label='positive rate',fc = 'b')
    for k in range(len(x)):
        x[k] = x[k] + width
    plt.bar(x, value_list_neg[i:j], width=width, label='negative rate',tick_label = word_list_neg[i:j],fc = 'r')
    plt.legend()
    plt.xticks(rotation=90)
    plt.show()
    i += 10
    j += 10
    if i >70 and j >80:
        break
